# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#data loading 
set1=pd.read_csv('/Users/niranjansmac/Downloads/archive 2/IMDb_Dataset.csv')
set2=pd.read_csv('/Users/niranjansmac/Downloads/archive 2/IMDb_Dataset_2.csv')
set3=pd.read_csv('/Users/niranjansmac/Downloads/archive 2/IMDb_Dataset_3.csv')

# %%
set1.isna().any()
# Out:
# Title                 False
# IMDb Rating           False
# Year                  False
# Certificates          False
# Genre                 False
# Director              False
# Star Cast             False
# MetaScore             False
# Duration (minutes)    False
# dtype: bool

# %%
set2.isna().sum()
# Out:
# Title                 0
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Poster-src            0
# Duration (minutes)    0
# dtype: int64

# %%
set3.isna().sum()
# Out:
# Title                 0
# Director              0
# Star Cast             0
# Year                  0
# IMDb Rating           0
# MetaScore             0
# Certificates          0
# Genre                 0
# Second_Genre          0
# Third_Genre           0
# Poster-src            0
# Duration (minutes)    0
# dtype: int64

# %%
set1.duplicated().sum()
# Out:
# 145

# %%
set1.drop_duplicates(inplace=True)

# %%
set2.duplicated().sum()
# Out:
# 411

# %%
set2.drop_duplicates(inplace=True)

# %%
set3.duplicated().sum()
# Out:
# 0

# %%
set1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 255 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               255 non-null    object
#  1   IMDb Rating         255 non-null    float64
#  2   Year                255 non-null    int64
#  3   Certificates        255 non-null    object
#  4   Genre               255 non-null    object
#  5   Director            255 non-null    object
#  6   Star Cast           255 non-null    object
#  7   MetaScore           255 non-null    float64
#  8   Duration (minutes)  255 non-null    float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 19.9+ KB

# %%
set2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2762 entries, 0 to 3172
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               2762 non-null   object
#  1   IMDb Rating         2762 non-null   float64
#  2   Year                2762 non-null   int64
#  3   Certificates        2762 non-null   object
#  4   Genre               2762 non-null   object
#  5   Director            2762 non-null   object
#  6   Star Cast           2762 non-null   object
#  7   MetaScore           2762 non-null   float64
#  8   Poster-src          2762 non-null   object
#  9   Duration (minutes)  2762 non-null   float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 237.4+ KB

# %%
set3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               1000 non-null   object
#  1   Director            1000 non-null   object
#  2   Star Cast           1000 non-null   object
#  3   Year                1000 non-null   int64
#  4   IMDb Rating         1000 non-null   float64
#  5   MetaScore           1000 non-null   float64
#  6   Certificates        1000 non-null   object
#  7   Genre               1000 non-null   object
#  8   Second_Genre        1000 non-null   object
#  9   Third_Genre         1000 non-null   object
#  10  Poster-src          1000 non-null   object
#  11  Duration (minutes)  1000 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 93.9+ KB

# %%
set1.describe()
# Out:
#        IMDb Rating         Year   MetaScore  Duration (minutes)
# count   255.000000   255.000000  255.000000          255.000000
# mean      7.173333  2014.207843   67.613333          117.953725
# std       0.952243    14.026126   15.050105           22.620083
# min       3.900000  1939.000000   26.000000           80.000000
# 25%       6.700000  2008.000000   59.000000          102.000000
# 50%       7.100000  2022.000000   67.000000          116.300000
# 75%       7.850000  2024.000000   78.000000          126.000000
# max       9.200000  2025.000000  100.000000          206.000000

# %%
set2.describe()
# Out:
#        IMDb Rating         Year    MetaScore  Duration (minutes)
# count  2762.000000  2762.000000  2762.000000         2762.000000
# mean      6.898371  2004.443881    65.755612          115.241781
# std       0.809457    16.955123    10.863215           21.184385
# min       3.900000  1917.000000    20.000000           46.000000
# 25%       6.400000  1997.000000    65.000000          105.000000
# 50%       6.900000  2010.000000    66.000000          116.300000
# 75%       7.400000  2016.000000    67.000000          120.000000
# max       9.500000  2025.000000   100.000000          317.000000

# %%
set3.describe()
# Out:
#               Year  IMDb Rating    MetaScore  Duration (minutes)
# count  1000.000000  1000.000000  1000.000000         1000.000000
# mean   2003.178000     6.418700    57.077100          100.034000
# std      18.697216     0.943064    15.051861           17.032938
# min    1921.000000     4.000000    11.000000           55.000000
# 25%    1995.000000     5.800000    48.000000           90.000000
# 50%    2007.500000     6.400000    57.100000           98.000000
# 75%    2017.000000     7.100000    66.000000          106.000000
# max    2024.000000     8.600000    99.000000          260.000000

# %%
set2.columns
# Out:
# Index(['Title', 'IMDb Rating', 'Year', 'Certificates', 'Genre', 'Director',
#        'Star Cast', 'MetaScore', 'Poster-src', 'Duration (minutes)'],
#       dtype='object')

# %%
set2.head()
# Out:
#                           Title  IMDb Rating  Year Certificates        Genre  \
# 0              End of the Spear          6.8  2005        PG-13    Adventure
# 1                Elvira Madigan          7.0  1967           PG    Biography
# 2  The Kid Stays in the Picture          7.3  2002            R  Documentary
# 3                 It Ain't Over          8.2  2022           PG  Documentary
# 4                        Mahler          7.0  1974           PG    Biography
#
#            Director                                   Star Cast  MetaScore  \
# 0         Jim Hanon         Louie LeonardoChad AllenJack Guzman       45.0
# 1      Bo Widerberg  Pia DegermarkThommy BerggrenLennart Malmer       66.0
# 2  Nanette Burstein          Robert EvansEddie AlbertPeter Bart       75.0
# 3       Sean Mullin          Andy AndresRoger AngellMarty Appel       79.0
# 4       Ken Russell      Robert PowellGeorgina HaleLee Montague       66.0
#
# ...

# %%
#count of every column in dataset
for column in set1:
    plt.figure(figsize=(20, 5)) 
    sns.countplot(x=column,data=set1)
    plt.title(f'Distribution of {column}')
    plt.show()

# %%
for column in set2:
    plt.figure(figsize=(20, 5)) 
    sns.countplot(x=column,data=set2)
    plt.title(f'Distribution of {column}')
    plt.show()

# %%
for column in set3:
    plt.figure(figsize=(20, 5)) 
    sns.countplot(x=column,data=set3)
    plt.title(f'Distribution of {column}')
    plt.show()

# %%
#details of a given movie name
n=input("Enter movie name")
movie=set2[set2["Title"].str.contains(n,case=False,na=False)]
if not movie.empty:
    for _, row in movie.iterrows():
        print(f"Title: {row['Title']}")
        print(f"Year: {row['Year']}")
        print(f"Rating: {row['IMDb Rating']}")
        print(f"Genres: {row['Genre']}")
        print(f"Director: {row['Director']}")
else:
    print("Movie not found.")
# Out:
# Enter movie name Elvira Madigan
# Title: Elvira Madigan
# Year: 1967
# Rating: 7.0
# Genres: Biography
# Director: Bo Widerberg

# %%
#data of movies relesed in specific year
class year:
    def info_year(n):
        year=set2[set2['Year']==n]
        if not year.empty:
            for _, row in year.iterrows():
                print(f"Title: {row['Title']}")
                print(f"Year: {row['Year']}")
                print(f"Rating: {row['IMDb Rating']}")
                print(f"Genres: {row['Genre']}")
                print(f"Director: {row['Director']}")
        else:
            print("No movies found for the specified year.")
    n=int(input())
    info_year(n)
# Out:
#  2020
# Title: Percy Vs Goliath
# Year: 2020
# Rating: 6.4
# Genres: Biography
# Director: Clark Johnson
# Title: The Glorias
# Year: 2020
# Rating: 6.0
# Genres: Biography
# Director: Julie Taymor
# Title: Adam
# Year: 2020
# Rating: 6.5
# Genres: Biography
# Director: Michael Uppendahl
# Title: Son of the South
# Year: 2020
# Rating: 6.2
# Genres: Biography
# Director: Barry Alexander Brown
# Title: Aline
# Year: 2020
# Rating: 6.3
# Genres: Biography
# Director: Valérie Lemercier
# Title: Dream Horse
# Year: 2020
# Rating: 6.9
# Genres: Biography
# Director: Euros Lyn
# Title: Safety
# Year: 2020
# Rating: 6.8
# Genres: Biography
# Director: Reginald Hudlin
# Title: Resistance
# Year: 2020
# Rating: 6.5
# Genres: Biography
# Director: Jonathan Jakubowicz
# Title: Sergio
# Year: 2020
# Rating: 6.2
# Genres: Biography
# Director: Greg Barker
# Title: The Duke
# Year: 2020
# Rating: 6.9
# Genres: Biography
# Director: Roger Michell
# Title: Shirley
# Year: 2020
# Rating: 6.1
# ...

# %%
#acquiring data based on Genre
class genre:
    def genre_(n):
        genre=set2[set2['Genre'].str.contains(n,case=False,na=False)]
        if not genre.empty:
            for _, row in genre.iterrows():
                print(f"title:{row['Title']}")
                print(f"year:{row['Year']}")
                print(f"Rating:{row['IMDb Rating']}")
                print(f"Director: {row['Director']}")
                print(f"Genre: {row['Genre']}")
        else:
            print("Invalid input")
    n=input('enter Genre: ')
    genre_(n)
# Out:
# enter Genre:  action
# title:Mesrine: Public Enemy No. 1
# year:2008
# Rating:7.4
# Director: Jean-François Richet
# Genre: Action
# title:The Hunter
# year:1980
# Rating:6.2
# Director: Buzz Kulik
# Genre: Action
# title:The Red Baron
# year:2008
# Rating:6.3
# Director: Nikolai Müllerschön
# Genre: Action
# title:The Message
# year:1976
# Rating:8.9
# Director: Moustapha Akkad
# Genre: Action
# title:Dillinger
# year:1973
# Rating:6.9
# Director: John Milius
# Genre: Action
# title:Into the White
# year:2012
# Rating:7.1
# Director: Petter Næss
# Genre: Action
# title:Mesrine: Killer Instinct
# year:2008
# Rating:7.5
# Director: Jean-François Richet
# Genre: Action
# title:Ip Man 3
# year:2015
# Rating:7.0
# Director: Wilson Yip
# Genre: Action
# title:Heaven & Earth
# year:1993
# Rating:6.8
# Director: Oliver Stone
# Genre: Action
# title:Ned Kelly
# year:2003
# Rating:6.4
# Director: Gregor Jordan
# Genre: Action
# title:The Baader Meinhof Complex
# year:2008
# Rating:7.3
# ...

# %%
#acquiring data based on director
class director:
    def director(n):
        director=set2[set2['Director'].str.contains(n,case=False,na=False)]
        if not director.empty:
            for _, row in director.iterrows():
                print(f"title:{row['Title']}")
                print(f"year:{row['Year']}")
                print(f"Rating:{row['IMDb Rating']}")
                print(f"Director: {row['Director']}")
                print(f"Genre: {row['Genre']}")
        else:
            print("Invalid input")
    n=input('enter director name: ')
    director(n)
# Out:
# enter director name:  Sean Mullin
# title:It Ain't Over
# year:2022
# Rating:8.2
# Director: Sean Mullin
# Genre: Documentary

# %%
set2.head()
# Out:
#                           Title  IMDb Rating  Year Certificates        Genre  \
# 0              End of the Spear          6.8  2005        PG-13    Adventure
# 1                Elvira Madigan          7.0  1967           PG    Biography
# 2  The Kid Stays in the Picture          7.3  2002            R  Documentary
# 3                 It Ain't Over          8.2  2022           PG  Documentary
# 4                        Mahler          7.0  1974           PG    Biography
#
#            Director                                   Star Cast  MetaScore  \
# 0         Jim Hanon         Louie LeonardoChad AllenJack Guzman       45.0
# 1      Bo Widerberg  Pia DegermarkThommy BerggrenLennart Malmer       66.0
# 2  Nanette Burstein          Robert EvansEddie AlbertPeter Bart       75.0
# 3       Sean Mullin          Andy AndresRoger AngellMarty Appel       79.0
# 4       Ken Russell      Robert PowellGeorgina HaleLee Montague       66.0
#
# ...

# %%
#acquiring data based on cast
class cast:
    def actor(n):
        actor=set2[set2['Star Cast'].str.contains(n,case=False,na=False)]
        if not actor.empty:
            for _, row in actor.iterrows():
                print(f"cast:{row['Star Cast']}")
                print(f"title:{row['Title']}")
                print(f"year:{row['Year']}")
                print(f"Rating:{row['IMDb Rating']}")
                print(f"Director: {row['Director']}")
                print(f"Genre: {row['Genre']}")
        else:
            print("Invalid input")
    n=input('enter actor name: ')
    actor(n)
# Out:
# enter actor name:  robert
# cast:Robert EvansEddie AlbertPeter Bart
# title:The Kid Stays in the Picture
# year:2002
# Rating:7.3
# Director: Nanette Burstein
# Genre: Documentary
# cast:Robert PowellGeorgina HaleLee Montague
# title:Mahler
# year:1974
# Rating:7.0
# Director: Ken Russell
# Genre: Biography
# cast:Louis NucéraMarcel PagnolYves Robert
# title:My Father's Glory
# year:1990
# Rating:7.6
# Director: Yves Robert
# Genre: Adventure
# cast:David P. HarmonCharles BeaumontWilliam Roberts
# title:The Wonderful World of the Brothers Grimm
# year:1962
# Rating:6.4
# Director: Henry Levin
# Genre: Adventure
# cast:Robert BudreauDaniel LangJames Luscombe
# title:Stockholm
# year:2018
# Rating:6.1
# Director: Robert Budreau
# Genre: Biography
# cast:Robert PattinsonDane DeHaanPeter Lucas
# title:Life
# year:2015
# Rating:6.0
# Director: Anton Corbijn
# Genre: Biography
# cast:Richard HarrisAlec GuinnessRobert Morley
# title:Cromwell
# year:1970
# Rating:7.0
# Director: Ken Hughes
# ...
